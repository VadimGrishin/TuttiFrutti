# %%
import json
import psycopg2
import pandas as pd
import numpy as np

import requests
import urllib
import zipfile

import os
from functools import reduce
import io
from sqlalchemy import create_engine

# %%
def convert4null(var):
    '''
    служебная функция для промежуточного преобразования Nan в null
    '''
    if pd.isna(var):
        return '#@$'
    
    return var

# %%
def fill_item_type(myzip):
    '''
    upsert справочника:
    DB.item_type  <- course_item_types.csv
    '''
    with myzip.open('course_item_types.csv') as from_archive:
        df_item_type = pd.read_csv(from_archive)
    
    print(len(df_item_type))
    
    df_item_type = df_item_type.rename(columns={'course_item_type_id':'id', 'course_item_type_desc':'descr', 
                             'course_item_type_category':'categ', 'course_item_type_graded':'graded'})
    df_item_type.drop(['atom_content_type_id'], axis='columns', inplace=True)
    
    
    # пишем во временную таблицу
    df_item_type.to_sql('tmp', engine, if_exists='replace')
    
    conn=engine.raw_connection()
    cur = conn.cursor()
    
    # upsert из временной таблицы в item_type
    sql = 'INSERT INTO coursera_structure.item_type \
    (select id, descr, categ, cast(graded as boolean) from tmp) \
    ON CONFLICT (id) DO NOTHING'
    cur.execute(sql)
    
    conn.commit()

# %%
def fill_assm_type(myzip):
    '''
    upsert справочника:
    assessment_type <- assessment_types.csv
    '''
    with myzip.open('assessment_types.csv') as from_archive:
        df_assmm_type = pd.read_csv(from_archive)
    
    print(len(df_assmm_type))
    
    df_assmm_type = df_assmm_type.rename(columns={'assessment_type_id':'id', 'assessment_type_desc':'descr'})

    # пишем во временную таблицу
    df_assmm_type.to_sql('tmp', engine, if_exists='replace')
    
    conn=engine.raw_connection()
    cur = conn.cursor()
    
    # upsert из временной таблицы в assessment_type
    sql = 'INSERT INTO coursera_structure.assessment_type \
    (select id, descr from tmp) \
    ON CONFLICT (id) DO NOTHING'
    cur.execute(sql)
    
    conn.commit()

# %%
def fill_que_type(myzip):
    '''
    upsert справочника:
    question_type <- assessment_question_types.csv
    '''
    with myzip.open('assessment_question_types.csv') as from_archive:
        df_assmm_type = pd.read_csv(from_archive)
    
    print(len(df_assmm_type))
    
    df_assmm_type = df_assmm_type.rename(columns={'assessment_question_type_id':'id', 'assessment_question_type_desc':'descr'})

    # пишем во временную таблицу
    df_assmm_type.to_sql('tmp', engine, if_exists='replace')
    
    conn=engine.raw_connection()
    cur = conn.cursor()
    
    # upsert из временной таблицы в assessment_type
    sql = 'INSERT INTO coursera_structure.question_type \
    (select id, descr from tmp) \
    ON CONFLICT (id) DO NOTHING'
    cur.execute(sql)
    
    conn.commit()

# %%
engine = create_engine('postgresql+psycopg2://postgres:pg215@VM-AS494:5432/test')
def upsert_reference_tables(zipname):
    print(zipname)

    myzip = zipfile.ZipFile(f'Coursera/{zipname}')
    fill_item_type(myzip)
    fill_assm_type(myzip)
    fill_que_type(myzip)

# %%
upsert_reference_tables('bayesian_methods_in_machine_learning_1578903839471.zip')
# Out:
# bayesian_methods_in_machine_learning_1578903839471.zip
# 27
# 7
# 14

# %%
def add_load(zipname):
    """
    Проверяет наличие загрузки в базе и при отсутствии - добавляет запись в coursera_structure.load
    """
    
    cursor.execute(f"select id from coursera_structure.load where name='{zipname[:-4]}'")
    
    if cursor.fetchone():
        print(f'Срез курса {zipname} уже в базе')
        return False
    else:
        cursor.execute(f"insert into coursera_structure.load (name, load_ts) values('{zipname[:-4]}', now()) returning id")
        return cursor.fetchone()[0]

# %%
def add_course(myzip, load_id):
    '''
    DB.course  | courses.csv
    ----------------------------
    id  -  (series nextval)
    ext_id  <-   course_id
    slug    <-   course_slug
    name    <-   course_name
    descr   <-   course_desc
    load_id - current load.id
    '''
    with myzip.open('courses.csv') as from_archive:
        df = pd.read_csv(from_archive, escapechar='\\')
    
    
    for index, row in df.iterrows():
        ext_id = row['course_id']
        slug = row['course_slug']
        name = row['course_name'].replace("'","''")
        desc = convert4null(row['course_desc']).replace("'","''")
        
        course_tmpdf = pd.read_sql_query(f"select * from coursera_structure.course where slug='{slug}' and ext_id is null", conn)
        
        # поскольку слаги всех курсов были залиты в базу заранее:
        if course_tmpdf.shape[0] > 0:
            # заполнить остальные поля в текущей строке, если слаг еще не "привлекался"
            id_ = course_tmpdf['id'].values[0]
            sql = f"update coursera_structure.course \
             set (ext_id, name, descr, load_id) = ('{ext_id}', '{name}', '{desc}', {load_id}) \
             where id={id_}"
        else:
            # если нет слага с пустым курсом, добавить новый курс
            sql = f"insert into coursera_structure.course (ext_id, slug, name, descr, load_id) \
                           values ('{ext_id}', '{slug}', '{name}', '{desc}', {load_id})"    
            
        # print(sql)
        cursor.execute(sql)
     
    return 0

# %%
def add_branch(myzip, load_id):
    '''
    DB.branch   | course_branches.csv
    ----------------------------
    id          - (series nextval)
    course_id   - (FK from course.id) <- course_id
    created_ts  <- authoring_course_branch_created_ts
    ext_id      <- course_branch_id
    load_id     - (current load.id)
    '''
    
    with myzip.open('course_branches.csv') as from_archive:
        df = pd.read_csv(from_archive, parse_dates=['authoring_course_branch_created_ts'], escapechar='\\')
    
    course_ext_id = '' 
    for index, row in df.iterrows():
        # course.id Postgres'а для внешнего ключа:
        if course_ext_id != row['course_id']: # в данном случае лишнее, но на будущее
            course_ext_id = row['course_id']
            course_sql = f"select id from coursera_structure.course where load_id={load_id} and ext_id='{course_ext_id}'"
            course_id = pd.read_sql_query(course_sql, conn)['id'].values[0] 
        
        created_ts = convert4null(row['authoring_course_branch_created_ts'])
        ext_id = row['course_branch_id']
        
        sql = f"insert into coursera_structure.branch (course_id, ext_id, created_ts, load_id) \
                        values ({course_id}, '{ext_id}', '{created_ts}', {load_id})".replace("'#@$'", "null")
        
        cursor.execute(sql)
        
    return 0

# %%
def add_module(myzip, load_id):
    '''
    DB.module     | course_branch_modules.csv 
    ----------------------------
    id            - (series nextval)
    branch_id     - (FK from branch.id)  <- course_branch_id
    branch_ext_id <- course_branch_id
    ext_id        <- course_module_id
    ord           <- course_branch_module_order
    name          <- course_branch_module_name
    descr         <- course_branch_module_desc
    load_id       - (current load.id)
    '''
    
    with myzip.open('course_branch_modules.csv') as from_archive:
        df = pd.read_csv(from_archive, escapechar='\\')
    df = df.sort_values(by=['course_branch_id'])
     
    branch_ext_id = ''
    for index, row in df.iterrows():
        # branch.id Postgres'а для внешнего ключа:
        if branch_ext_id != row['course_branch_id']:
            branch_ext_id = row['course_branch_id']
            branch_sql = f"select id from coursera_structure.branch where load_id={load_id} and ext_id='{branch_ext_id}'"
            branch_id = pd.read_sql_query(branch_sql, conn)['id'].values[0]
        
        ext_id = row['course_module_id']
        ord_   = row['course_branch_module_order']
        name   = row['course_branch_module_name'].replace("'","''")
        descr  = convert4null(row['course_branch_module_desc']).replace("'","''")
        
        sql = f"insert into coursera_structure.module (branch_id, branch_ext_id, ext_id, ord, name, descr, load_id) \
                        values ({branch_id}, '{branch_ext_id}', '{ext_id}', {ord_}, '{name}', '{descr}', {load_id})"
        
        cursor.execute(sql)
        
    return 0

# %%
def add_lesson(myzip, load_id):
    '''
    DB.lesson     | course_branch_lessons.csv
    ----------------------------
    id            - (series nextval)
    module_id  - (FK from module.id) <- course_branch_id, course_module_id
    branch_ext_id <- course_branch_id
    ext_id        <- course_lesson_id
    ord           <- course_branch_lesson_order
    name          <- course_branch_lesson_name
    load_id       - (current load.id)
    '''
    
    with myzip.open('course_branch_lessons.csv') as from_archive:
        df = pd.read_csv(from_archive, escapechar='\\')
    df = df.sort_values(by=['course_branch_id', 'course_module_id'])
     
    branch_ext_id = ''
    module_ext_id = ''
    for index, row in df.iterrows():
        # module.id Postgres'а для внешнего ключа:
        if branch_ext_id != row['course_branch_id'] or module_ext_id != row['course_module_id']:
            branch_ext_id = row['course_branch_id']
            module_ext_id = row['course_module_id']
            module_sql = f"select id from coursera_structure.module where load_id={load_id} and\
             branch_ext_id='{branch_ext_id}' and ext_id='{module_ext_id}'"
            module_id = pd.read_sql_query(module_sql, conn)['id'].values[0]

        ext_id = row['course_lesson_id']
        ord_   = row['course_branch_lesson_order']
        name   = row['course_branch_lesson_name'].replace("'","''")

        sql = f"insert into coursera_structure.lesson (module_id, branch_ext_id, ext_id, ord, name, load_id) \
                        values ({module_id}, '{branch_ext_id}', '{ext_id}', {ord_}, '{name}', {load_id})"
        
        cursor.execute(sql)
        
    return 0

# %%
def add_item(myzip, load_id):
    '''
    DB.item       | course_branch_items.csv
    ----------------------------
    id            - (series nextval)
    lesson_id  - (FK from lesson.id) <- course_branch_id, course_lesson_id
    branch_ext_id <- course_branch_id
    ext_id        <- course_item_id
    
    type_id       <- course_item_type_id
    ord           <- course_branch_item_order
    name          <- course_branch_item_name
    
    optional      <- course_branch_item_optional
    graded        <- is_graded
    
    load_id       - (current load.id)
    '''

    with myzip.open('course_branch_items.csv') as from_archive:
        df = pd.read_csv(from_archive, escapechar='\\')
    df = df.sort_values(by=['course_branch_id', 'course_lesson_id'])
     
    branch_ext_id = ''
    lesson_ext_id = ''
    for index, row in df.iterrows():
        # lesson.id Postgres'а для внешнего ключа:
        if branch_ext_id != row['course_branch_id'] or lesson_ext_id != row['course_lesson_id']:
            branch_ext_id = row['course_branch_id']
            lesson_ext_id = row['course_lesson_id']
            lesson_sql = f"select id from coursera_structure.lesson where load_id={load_id} and\
             branch_ext_id='{branch_ext_id}' and ext_id='{lesson_ext_id}'"
            lesson_id = pd.read_sql_query(lesson_sql, conn)['id'].values[0]

        ext_id   = row['course_item_id']
        type_id  = row['course_item_type_id']
        ord_     = row['course_branch_item_order']
        name     = row['course_branch_item_name'].replace("'","''")
        optional = row['course_branch_item_optional']
        graded   = 'f'#row['is_graded'] !!! - не во всех версиях загрузок (срез курса) есть это поле

        sql = \
        f"insert into coursera_structure.item (lesson_id, branch_ext_id, ext_id, type_id, ord, name, optional, graded, load_id) \
        values ({lesson_id}, '{branch_ext_id}', '{ext_id}', {type_id}, {ord_}, '{name}', '{optional}', '{graded}', {load_id})"
        
        cursor.execute(sql)
        
    return 0

# %%
def add_assessment(myzip, load_id):
    '''
    DB.assessment     | assessments.csv
    ----------------------------
    id            - (series nextval)
    ext_id        <- assessment_id
    
    type_id       <- assessment_type_id
    update_ts     <- assessment_update_ts
    passing_fract <- assessment_passing_fraction

    load_id       - (current load.id)
    '''

    with myzip.open('assessments.csv') as from_archive:
        df = pd.read_csv(from_archive, parse_dates=['assessment_update_ts'])
         
    for index, row in df.iterrows():
        ext_id    = row['assessment_id']
        type_id   = row['assessment_type_id']
        update_ts = convert4null(row['assessment_update_ts'])
        passing_fract = convert4null(row['assessment_passing_fraction']) 
        
        sql = \
        f"insert into coursera_structure.assessment (ext_id, type_id, update_ts, passing_fract, load_id) \
        values ('{ext_id}', {type_id}, '{update_ts}', {passing_fract}, {load_id})".replace("'#@$'", "null").\
        replace("#@$", "null")
        
        cursor.execute(sql)
        
    return 0

# %%
def add_question(myzip, load_id):
    '''
    DB.question   | assessment_questions.csv
    ----------------------------
    id            - (series nextval)
    ext_id        <- assessment_question_id
    
    type_id       <- assessment_question_type_id
    prompt        <- assessment_question_prompt
    update_ts     <- assessment_question_update_ts

    load_id       - (current load.id)
    '''

    with myzip.open('assessment_questions.csv') as from_archive:
        df = pd.read_csv(from_archive, escapechar='\\', parse_dates=['assessment_question_update_ts'])
         
    for index, row in df.iterrows():
        ext_id    = row['assessment_question_id']
        type_id   = row['assessment_question_type_id']
        prompt    = row['assessment_question_prompt'].replace("'","''")
        update_ts = convert4null(row['assessment_question_update_ts'])
        
        sql = \
        f"insert into coursera_structure.question (ext_id, type_id, prompt, update_ts, load_id) \
        values ('{ext_id}', {type_id}, '{prompt}', '{update_ts}', {load_id})".replace("'#@$'", "null")
        
        cursor.execute(sql)
        
    return 0

# %%
def add_item_assm(myzip, load_id):
    '''
    DB.item_assessment                       | course_branch_item_assessments.csv
    -----------------------------------------------------------------------------
    item_id        - (FK from item.id)       <- course_branch_id, course_item_id
    assessment_id  - (FK from assessment.id) <- assessment_id
    '''

    with myzip.open('course_branch_item_assessments.csv') as from_archive:
        df = pd.read_csv(from_archive)

    for index, row in df.iterrows():
        # item.id Postgres'а для внешнего ключа:
        branch_ext_id = row['course_branch_id']
        item_ext_id = row['course_item_id']
        item_sql = f"select id from coursera_structure.item where load_id={load_id} and\
         branch_ext_id='{branch_ext_id}' and ext_id='{item_ext_id}'"
        item_id = pd.read_sql_query(item_sql, conn)['id'].values[0]

        # assessment.id Postgres'а для внешнего ключа:
        assessment_ext_id = row['assessment_id']
        assessment_sql = f"select id from coursera_structure.assessment where load_id={load_id} and ext_id='{assessment_ext_id}'"
        assessment_id = pd.read_sql_query(assessment_sql, conn)['id'].values[0]

        sql = \
        f"insert into coursera_structure.item_assessment (item_id, assessment_id) \
        values ({item_id}, {assessment_id})"
        
        cursor.execute(sql)
        
    return 0

# %%
def add_assm_question(myzip, load_id):
    '''
    DB.assessment_question  | assessment_assessments_questions.csv
    -----------------------------------------------------------------------------
    assessment_id  - (FK from assessment.id) <- assessment_id
    question_id    - (FK from question.id)   <-  assessment_question_id
    internal_id         <-  assessment_question_internal_id
    cuepoint            <-  assessment_question_cuepoint
    ord                 <-  assessment_question_order
    weight              <-  assessment_question_weight
    '''

    with myzip.open('assessment_assessments_questions.csv') as from_archive:
        df = pd.read_csv(from_archive)
    
    for index, row in df.iterrows():
        # assessment.id Postgres'а для внешнего ключа:
        assm_ext_id = row['assessment_id']
        assessment_sql = f"select id from coursera_structure.assessment where load_id={load_id} and ext_id='{assm_ext_id}'"
        assessment_id = pd.read_sql_query(assessment_sql, conn)['id'].values[0]

        # question.id Postgres'а для внешнего ключа:
        question_ext_id = row['assessment_question_id']
        question_sql = f"select id from coursera_structure.question where load_id={load_id} and ext_id='{question_ext_id}'"
        question_id = pd.read_sql_query(question_sql, conn)['id'].values[0]
        
        internal_id   = row['assessment_question_internal_id']
        cuepoint  = convert4null(row['assessment_question_cuepoint'])
        ord_     = convert4null(row['assessment_question_order'])
        weight     = convert4null(row['assessment_question_weight'])

        sql = \
        f"insert into coursera_structure.assessment_question (assessment_id, question_id, internal_id, cuepoint, ord, weight) \
        values ({assessment_id}, {question_id}, '{internal_id}', {cuepoint}, {ord_}, {weight})".replace("#@$", "null")
        
        cursor.execute(sql)
        
    return 0

# %%
def add_option(myzip, load_id):
    '''
    DB.q_option       | assessment_options.csv
    ----------------------------
    id            - (series nextval)
    question_id  - (FK from question.id) <- assessment_question_id
    ext_id        <- assessment_option_id
    
    display       <- assessment_option_display
    feedback      <- assessment_option_feedback
    correct       <- assessment_option_correct
    index      <- assessment_option_index
    
    load_id       - (current load.id)
    '''

    with myzip.open('assessment_options.csv') as from_archive:
        df = pd.read_csv(from_archive, escapechar='\\')
    df = df.sort_values(by=['assessment_question_id'])
     
    question_ext_id = ''
    for index, row in df.iterrows():
        # lesson.id Postgres'а для внешнего ключа:
        if question_ext_id != row['assessment_question_id']:
            question_ext_id = row['assessment_question_id']
            question_sql = f"select id from coursera_structure.question where load_id={load_id} \
            and ext_id='{question_ext_id}'"
            question_id = pd.read_sql_query(question_sql, conn)['id'].values[0]

        ext_id   = row['assessment_option_id']
        display  = row['assessment_option_display'].replace("'","''")
        feedback = row['assessment_option_feedback'].replace("'","''")
        correct  = row['assessment_option_correct']
        index    = convert4null(row['assessment_option_index'])

        sql = \
        f"insert into coursera_structure.q_option (question_id, ext_id, display, feedback, correct, index, load_id) \
        values ({question_id}, '{ext_id}', '{display}', '{feedback}', '{correct}', {index}, {load_id})".replace("#@$", "null")
        
        cursor.execute(sql)
        
    return 0

# %%
def load_course_to_db(folder, zipname):
    '''
    Загрузка одного курса из архива (на данный момент - только структуры курса)
    '''
    
    load_id = add_load(zipname)
    if not load_id:
        return -1

    myzip = zipfile.ZipFile(f'{folder}/{zipname}')
    
    add_course(myzip, load_id)
    
    add_branch(myzip, load_id)
    
    add_module(myzip, load_id)
    
    add_lesson(myzip, load_id)
    
    add_item(myzip, load_id)
    
    add_assessment(myzip, load_id)
    
    add_item_assm(myzip, load_id)
    
    add_question(myzip, load_id)
    
    add_assm_question(myzip, load_id)

    add_option(myzip, load_id)
    
    conn.commit()

# %% [markdown]
# ### Загрузка архивов из папки

# %%
# соберем все архивы в список (архив = выгруженный из курсеры срез курса в формате *.zip)
folder = 'Coursera' #'\\\\VM-AS494\\Temp'   #'C:\\Users\\vgrishin\\vadim\\mk_an\\zip'
zip_list = list(filter(lambda x: x[-4:] == '.zip', os.listdir(folder)))
zip_list
# Out:
# ['algorithmic_toolbox_1579681812260.zip',
#  'bayesian_methods_in_machine_learning_1565260801251.zip',
#  'bayesian_methods_in_machine_learning_1574256885796.zip',
#  'bayesian_methods_in_machine_learning_1578903839471.zip',
#  'neuroeconomics_1579681772902.zip']

# %%
# %%time
# загрузка курсов по списку

conn = psycopg2.connect(dbname='test', user='postgres', 
                        password='pg215', host='VM-AS494')
cursor = conn.cursor()



for zipname in zip_list:
    
    load_course_to_db(folder, zipname)
# Out:
# Срез курса algorithmic_toolbox_1579681812260.zip уже в базе
# Срез курса bayesian_methods_in_machine_learning_1565260801251.zip уже в базе
# Срез курса bayesian_methods_in_machine_learning_1574256885796.zip уже в базе
# Срез курса bayesian_methods_in_machine_learning_1578903839471.zip уже в базе
# Wall time: 13 s

# %%
zip_list = zip_list[:1]
zip_list
# Out:
# ['algorithmic_toolbox_1565260799484.zip']

# %%
folder
# Out:
# 'C:\\Users\\vgrishin\\vadim\\mk_an\\zip'

# %%
myzip = zipfile.ZipFile(f'{folder}/{zip_list[0]}')
with myzip.open('assessment_questions.csv') as from_archive:
    df = pd.read_csv(from_archive, escapechar='\\')
df.shape
# Out:
# (1199, 6)

# %%
# Работа с типом столбца датафрейма
if type(df.iloc[0]['assessment_passing_fraction']) == np.float64:
    print(str(type(df.iloc[0]['assessment_passing_fraction'])).replace("class 'numpy.", ''))

# %%
import io

output = io.StringIO()
df_item_type.to_csv(output, sep='\t', header=False, index=False)
output.seek(0)
contents = output.getvalue()

# %%
conn.commit()

# %%
"Honor's track assignment".strip()
# Out:
# "Honor's track assignment"

# %%
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# <ipython-input-26-d1e5a1d63429> in <module>
#       4
#       5 for l in zip_list:
# ----> 6     cursor.execute(f"SELECT * FROM {l}")
#       7     print(cursor.fetchall()[0:2])
#       8     conn.commit()
#
# UndefinedTable: ОШИБКА:  отношение "bayesian_methods_in_machine_learning_1565260801251.zip" не существует
# LINE 1: SELECT * FROM bayesian_methods_in_machine_learning_156526080...
#                       ^

# %%
conn = psycopg2.connect(dbname='test', user='postgres', 
                        password='pg215', host='VM-AS494')
cursor = conn.cursor()

for name in ['openedu_structure.course', 'openedu_structure.chapter', 'openedu_structure.item']:
    cursor.execute(f"SELECT * FROM {name}")
    print(cursor.fetchall()[0])
    conn.commit()
# Out:
# (1, 'Основания алгебры и геометрии', 'hse+AGBASE+fall_2019', None)
# (7, 1, '11111', 'nnnnnnn')
# (561, 465, 'db61b97b8db74f069b1e12bd135824ff', 'video', 'Промо-ролик', None)

# %%
# Образец для быстрой загрузки через copy_from

conn = psycopg2.connect(dbname='test', user='postgres', 
                        password='pg215', host='VM-AS494')
cur = conn.cursor()

#engine = create_engine('postgresql+psycopg2://postgres:pg215@VM-AS494:5432/test')
#conn=engine.raw_connection()
#cur = conn.cursor()
output = io.StringIO()
df_item_type.to_csv(output, sep='\t', header=False, index=False)
output.seek(0)
contents = output.getvalue()
cur.copy_from(output, 'coursera_structure.item_type', null="") #null values become ''   
conn.commit()

INSERT INTO tablename (id, username, password, level, email) 
                VALUES (1, 'John', 'qwerty', 5, 'john@mail.com') 
ON CONFLICT (id) DO NOTHING
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# <ipython-input-5-8957b13e04ac> in <module>
#      10 output.seek(0)
#      11 contents = output.getvalue()
# ---> 12 cur.copy_from(output, 'coursera_structure.item_type', null="") #null values become ''
#      13 conn.commit()
#      14
#
# UniqueViolation: ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "item_type_pkey"
# DETAIL:  Ключ "(id)=(1)" уже существует.
# CONTEXT:  COPY item_type, строка 1

# %%
for d in df:
    print(d.shape)
# Out:
# (27351, 10)
# (30416, 10)
# (31913, 10)

# %%
df[2].shape
# Out:
# (31913, 10)

# %%
myzip = zipfile.ZipFile('bayesian_methods_in_machine_learning_1578903839471.zip')

# %%
with myzip.open('assessment_types.csv') as from_archive:
    df1 = pd.read_csv(from_archive)

# %%
myzip.close()

# %%
df1.sort_values(by='assessment_type_id')
# Out:
#    assessment_type_id assessment_type_desc
# 0                   1             in video
# 5                   2         course quick
# 3                   3     open single page
# 6                   4      quick questions
# 4                   5               survey
# 2                   6            formative
# 1                   7            summative

# %%
#for fname in myzip.namelist():
#    print(fname)

with myzip.open('assessment_actions.csv') as from_archive:
    df = pd.read_csv(from_archive, parse_dates=['assessment_action_ts', 'assessment_action_start_ts'])


#myzip.close()

# %%
# %%time
df.sort_values(by=['hse_user_id', 'assessment_action_ts'])
# Out:
# Wall time: 2.85 s
#                              assessment_action_id  \
# 584798   134aed120116815552efde9c156f9c2d883fd56f
# 612727   d30cac5a8bb0c0b6ec7a8655ac9d1edd33a16272
# 1232519  cbe210939e5d352a7da96e8a10f4ff0e9d6efd0c
# 903484   2a19d1c309ec70432400fb80a7a0c9c5acd2fc11
# 528516   ebac796845e44b13ce85c5b064ed01de18af8a87
# 1523168  5ae2f410cf12067130fed046171f54de02ee45e0
# 416441   0b4e59f3feb45df65f82b3c1dc7a016902d8b1fe
# 1355256  8ec9b463b4d3fcaabc08bba57a715b6e7c4f1342
# 1392760  91bd5e7c8ec19870a0297d0d9e563b3215e46081
# 70251    9864dd3cc2e19d6e589e0d3e37febeb24ce04dea
# 545356   041e461428a35287917fceb10e8ebced23c2b598
# 1455707  4c32139a05a0fb27e7410689162af53618fb5976
# 1127919  9606ae7aedadcd6537d4790378235aaf9529b7e5
# 731761   d2d8e684d281ecd8e3815c3a8b76339107647048
# 1070677  06c6106adb3ebe389ab487317caba5ce87219dc4
# 1436664  0d764709215bca8e215d91740eb9403186566200
# 1352875  c4b27f41cf2c3c0b7b6b7b9bbd13f4533ac19409
# 1390242  2847fce25c3b033b0ad0de142410ed705cc17d30
# 95635    a98b9c5eca026bad14e505ab34aa3d9b9ba10f28
# 217359   72ffd3bac77350407e33766ec2e0ca027a9f75b2
# 1530758  b0796e697c1887d03c4f527a009d5dd7a426b076
# 864141   4a524166907941a481aa3d62c6dde6e48ce7266a
# 996993   eda885a4fca06023585e9fea97691b548c4d8d96
# 1344914  8d9292a840df6f6b495dabe79fd7013750401ef0
# 340763   085403c7ad88ae4ac7dfea08be0fdc9b0aa74d4a
# 856271   8d18a13aa6b6298ff6c3edccf2c89138c76660ff
# 303408   79fd5c30745d5d648aeb59e97bc4192b7069f8eb
# 453070   d1993635c904dbd21ddbfeafcb9dc0754dfc9f03
# 1457254  c58fb1e9cb55f7d602518c295675b1a1cfef9cba
# 1588202  d5fb676ece3ebacc0e09eaa88e4eabb0343ae089
# ...                                           ...
# 1489673  f9c1684daff367097dc1b52a9c8a8626b4610789
# 1059174  da47533fc1847a6f719a7ae6f42ffaa2a0a48b63
# 1497540  451ccd9b4bae80d8b61d8b5e9c6c8498945c5a46
# 613013   3f7714ba539880632a2c459280812228ee8277d6
# 1696588  93b7a51cf4ff3e2c2fd73d565657574f5e554cb0
# 58320    533f32275faf96c9304716a13083b1b0f177693d
# 209055   b1c46a21b0f73cb555a715e44be8424f43973ef4
# 1452883  1f36a1ee89517b7e7cf5625823c1ca760158a8cc
# 1298909  ff2a76e2b30915dd3a27cd618bbc0f5082d59ccf
# 678955   1c3b97b1632335d1fc038cbbe399acb05d8bd1a5
# 1455503  af21b8923a5b2ee0b292a0b7cddae7eecc3926ba
# 697543   47af208639badef9ee2d5992926694de6c27a5a2
# 796360   f70ea26eea44236c15e2c4f1dac9b6b8c86a06fd
# 11463    6a05c8abacb154fc6c34c6a0e8478660cbb0b1e7
# 453128   39669c85f9be1705d279d42bb2cc172bdb2e3636
# 1073184  bbee99d55c5a1ed3e9adf0f5531b0e2c12d9b4b6
# 659654   4a8d313bc18e91b7c0754c4ea0bd4c15feb6f061
# 1710704  71570dbf17ee45fdd7b632f4fce7f2ddb31547bd
# 1785161  3733f224f86943f20ea8d1c40dfbd65ac5812447
# 1025836  2282c1412d34ff1031a498c1ab7a0d36750d29c5
# 1476196  bf0295efcb7aac523da01708758498e169080b2e
# 1016251  44acb74e6c3d3d868365c7ba09e3df31626d3c05
# 1494932  cd2517b04c8df6be0aa312755b918a15d133c29b
# 1336441  eca1ade58b48183b23de3eee6a7d2584f277f1ef
# 1401710  59093a0ae736e43644ab3978dec7a7f057eeb2f8
# 51237    e6127a06c86451cdfe28dc9d90f2800c488df147
# 688678   b922453ecfefe30b457fa72550776f31665cf021
# 1127812  8942b532e67b64f29d2abe1158cff8b7c2aec31a
# 1455610  90294c2ff8eaf9e0dcea532d94be4a44f9ef7bed
# 115683   4c8f2efe451d8f02cd5252258cbb593512eca958
#
#                         assessment_action_base_id              assessment_id  \
# 584798   2cb9284a9672b130e924bcd5c16b6ce730ea6c21   TPm_mZpLEeem4Q4WHq6hYA@5
# 612727   2cb9284a9672b130e924bcd5c16b6ce730ea6c21   TPm_mZpLEeem4Q4WHq6hYA@5
# 1232519  2cb9284a9672b130e924bcd5c16b6ce730ea6c21   TPm_mZpLEeem4Q4WHq6hYA@5
# 903484   2cb9284a9672b130e924bcd5c16b6ce730ea6c21   TPm_mZpLEeem4Q4WHq6hYA@5
# 528516   2cb9284a9672b130e924bcd5c16b6ce730ea6c21   TPm_mZpLEeem4Q4WHq6hYA@5
# 1523168  2cb9284a9672b130e924bcd5c16b6ce730ea6c21   TPm_mZpLEeem4Q4WHq6hYA@5
# 416441   061aeea26b9b80f1951e518ba8fefa0e15fd3428   YZp66ppOEeek-RKI0bJQ2g@4
# 1355256  061aeea26b9b80f1951e518ba8fefa0e15fd3428   YZp66ppOEeek-RKI0bJQ2g@4
# 1392760  65cc7ab87982fecc5cc0e8fa9fa0eea02a318500   YtA0hZpREeeKDBL2UWdiaA@5
# 70251    65cc7ab87982fecc5cc0e8fa9fa0eea02a318500   YtA0hZpREeeKDBL2UWdiaA@5
# 545356   ebc5f153b38a1d2fa34d21ed29bfe21c3c71f156   CXB1CJpSEeenWwpQEGTi4A@5
# 1455707  5aa57ce1c488ebd4bec808a33d990cc588ef9ca3   CXB1CJpSEeenWwpQEGTi4A@5
# 1127919  8290aaec82f6519556259592a4504d13fbd018ae   CXB1CJpSEeenWwpQEGTi4A@5
# 731761   dc1fa899867def4a46f102ab24f7d725cae5db80  99J-gnPIEeezeArbNjnUng@17
# 1070677  dc1fa899867def4a46f102ab24f7d725cae5db80  99J-gnPIEeezeArbNjnUng@17
# 1436664  71c0c1eba75d19a1aa52e17296fc3a9ec4b50af7   CXB1CJpSEeenWwpQEGTi4A@5
# 1352875  9ddb3d92cf6b431fd68464a9c6d49b88e465eda3   CXB1CJpSEeenWwpQEGTi4A@5
# 1390242  339fb64579a460d5192e76273e3fcf23fa0dcc40   CXB1CJpSEeenWwpQEGTi4A@5
# 95635    2868cda85c3617c7b13b0efe75c4c247bfcbfdbe   CXB1CJpSEeenWwpQEGTi4A@5
# 217359   19710f8019d7159f0e13e90f43ead9ae391f0185   CXB1CJpSEeenWwpQEGTi4A@5
# 1530758  7dd0addd549308259a33c1eaa0091c8a56288ac3   CXB1CJpSEeenWwpQEGTi4A@5
# 864141   7cb18ce44ef6603c354a94a13c3ecbbca46320ea   CXB1CJpSEeenWwpQEGTi4A@5
# 996993   fe526276bbeabf733433d6c225fd959ed550535f   R_HHUJpTEeedwg5NNrc5Mg@4
# 1344914  d3838ce3b0ba77688735f13ce0798ce52da9e2ff   R_HHUJpTEeedwg5NNrc5Mg@4
# 340763   1af5a7427f2484a9488f6a534318ba8e1764f320   R_HHUJpTEeedwg5NNrc5Mg@4
# 856271   45974d729b4471c858de729571baf33642cae6a8   TPm_mZpLEeem4Q4WHq6hYA@4
# 303408   45974d729b4471c858de729571baf33642cae6a8   TPm_mZpLEeem4Q4WHq6hYA@4
# 453070   45974d729b4471c858de729571baf33642cae6a8   TPm_mZpLEeem4Q4WHq6hYA@4
# 1457254  45974d729b4471c858de729571baf33642cae6a8   TPm_mZpLEeem4Q4WHq6hYA@4
# 1588202  45974d729b4471c858de729571baf33642cae6a8   TPm_mZpLEeem4Q4WHq6hYA@4
# ...                                           ...                        ...
# 1489673  89d12a796c303cfbaea3e7f914c75f5bb077aac9   ubawvI8sEeeGWgr92ai58A@6
# 1059174  ab5056f0dc6d215dd03f54608b04df233bbafc3d   xCnt03n1EeezGQp6YRZP7g@9
# 1497540  5bdd28f5a22ca70c663b3de3bfe70ca1971e68ba   lHHEm6nDEeep5g4OtXDhXA@2
# 613013   0372a954115cb5690f18901a0508df265cd08e2b   TnvGQ6FBEee8nQ6uE8a7OA@4
# 1696588  28b22de0e56fefbfe22430ab3790652a41bf33a8   zR-NWaFCEeeJkxJMUXGH_g@4
# 58320    8380758be65abd2650cf96a088025d0da9ca257a   CXB1CJpSEeenWwpQEGTi4A@4
# 209055   bd3eacfe76c32a2f3acf726098d96acfe79ee407   R_HHUJpTEeedwg5NNrc5Mg@3
# 1452883  02ef725f6df26e0765653d34e2c899f06a1e0a70   zR-NWaFCEeeJkxJMUXGH_g@4
# 1298909  b25ce66dedfc3f96aad55e7e7e24e3ae49a86ec5   X--mla_8Eee_fRI_mF2vhg@2
# 678955   49d402ef040a48f9f8e58f95906ea77bcfe40067   X--mla_8Eee_fRI_mF2vhg@2
# 1455503  8f3166cf1bab6b50d8240d869ac9701fb72a8d4c   CUb2baE6EeehgxLmA_UEiA@4
# 697543   07c18e29d5c99d9825e1628c09ef8f659f239ce6   TnvGQ6FBEee8nQ6uE8a7OA@4
# 796360   a9a1b675510ced595c2b91d4249ec4bf85f7d6c0   2mcHsaFFEeeuIA64ZD0A-A@2
# 11463    aacb9251b6b728f2262a445b7ce04617eb5045a0   CXB1CJpSEeenWwpQEGTi4A@4
# 453128   865aa7279769d677bc0d784b952b4bd225f484da   TPm_mZpLEeem4Q4WHq6hYA@4
# 1073184  1fc32d2ec71cb9cfe4d87138c9224b434c0efd92   TPm_mZpLEeem4Q4WHq6hYA@4
# 659654   1fc32d2ec71cb9cfe4d87138c9224b434c0efd92   TPm_mZpLEeem4Q4WHq6hYA@4
# 1710704  1fc32d2ec71cb9cfe4d87138c9224b434c0efd92   TPm_mZpLEeem4Q4WHq6hYA@4
# 1785161  1fc32d2ec71cb9cfe4d87138c9224b434c0efd92   TPm_mZpLEeem4Q4WHq6hYA@4
# 1025836  1fc32d2ec71cb9cfe4d87138c9224b434c0efd92   TPm_mZpLEeem4Q4WHq6hYA@4
# 1476196  1fc32d2ec71cb9cfe4d87138c9224b434c0efd92   TPm_mZpLEeem4Q4WHq6hYA@4
# 1016251  1fc32d2ec71cb9cfe4d87138c9224b434c0efd92   TPm_mZpLEeem4Q4WHq6hYA@4
# 1494932  1fc32d2ec71cb9cfe4d87138c9224b434c0efd92   TPm_mZpLEeem4Q4WHq6hYA@4
# 1336441  f466b08859ad6dc62a7db25ef14b63462ce3facc   YZp66ppOEeek-RKI0bJQ2g@3
# 1401710  f466b08859ad6dc62a7db25ef14b63462ce3facc   YZp66ppOEeek-RKI0bJQ2g@3
# 51237    f466b08859ad6dc62a7db25ef14b63462ce3facc   YZp66ppOEeek-RKI0bJQ2g@3
# 688678   1e92effaede9def9eee51c82b855580f514c1a43   YtA0hZpREeeKDBL2UWdiaA@3
# 1127812  006d39a39732e1f2c9502c124030af6bc04105cf   CXB1CJpSEeenWwpQEGTi4A@4
# 1455610  006d39a39732e1f2c9502c124030af6bc04105cf   CXB1CJpSEeenWwpQEGTi4A@4
# 115683   0d257d595c17557bf1705b33dc97a614c91b28ac   R_HHUJpTEeedwg5NNrc5Mg@3
#
#                        assessment_scope_id  assessment_scope_type_id  \
# 584798   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 612727   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1232519  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 903484   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 528516   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1523168  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 416441   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1355256  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1392760  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 70251    opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 545356   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1455707  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1127919  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 731761   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1070677  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1436664  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1352875  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1390242  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 95635    opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 217359   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1530758  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 864141   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 996993   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1344914  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 340763   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 856271   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 303408   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 453070   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1457254  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1588202  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# ...                                    ...                       ...
# 1489673  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1059174  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1497540  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 613013   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1696588  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 58320    opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 209055   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1452883  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1298909  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 678955   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1455503  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 697543   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 796360   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 11463    opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 453128   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1073184  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 659654   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1710704  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1785161  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1025836  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1476196  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1016251  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1494932  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1336441  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1401710  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 51237    opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 688678   opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1127812  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 1455610  opencourse~anas83IDEeenOwpmZ1LH1g                         6
# 115683   opencourse~anas83IDEeenOwpmZ1LH1g                         6
#
#          assessment_action_version       assessment_action_ts  \
# 584798                           1 2019-03-31 15:42:52.503000
# 612727                           2 2019-03-31 16:00:00.359000
# 1232519                          3 2019-03-31 16:02:38.266000
# 903484                           4 2019-03-31 16:13:59.190000
# 528516                           5 2019-03-31 16:14:21.900000
# 1523168                          6 2019-03-31 16:14:33.271000
# 416441                           1 2019-03-31 16:14:50.097000
# 1355256                          2 2019-03-31 16:28:30.174000
# 1392760                          1 2019-03-31 16:56:38.740000
# 70251                            2 2019-03-31 17:18:15.432000
# 545356                           1 2019-03-31 17:20:18.775000
# 1455707                          1 2019-03-31 17:22:24.875000
# 1127919                          1 2019-03-31 17:24:56.927000
# 731761                           1 2019-03-31 17:35:18.125000
# 1070677                          2 2019-03-31 17:35:21.244000
# 1436664                          1 2019-03-31 17:37:32.671000
# 1352875                          1 2019-04-01 10:35:37.047000
# 1390242                          1 2019-04-01 10:35:50.912000
# 95635                            1 2019-04-01 14:02:33.671000
# 217359                           1 2019-04-02 19:10:19.587000
# 1530758                          1 2019-04-02 19:55:08.577000
# 864141                           1 2019-04-02 19:55:22.160000
# 996993                           1 2019-04-02 19:58:27.255000
# 1344914                          1 2019-04-02 19:58:32.288000
# 340763                           1 2019-04-02 19:59:42.460000
# 856271                           1 2019-01-18 06:18:37.730000
# 303408                           2 2019-01-18 07:16:28.405000
# 453070                           3 2019-01-18 07:19:24.067000
# 1457254                          4 2019-01-18 07:26:17.032000
# 1588202                          5 2019-01-18 07:26:25.758000
# ...                            ...                        ...
# 1489673                          1 2019-11-02 12:07:11.143670
# 1059174                          1 2019-11-02 12:07:38.040185
# 1497540                          1 2018-10-09 14:39:05.857000
# 613013                           1 2018-10-11 19:57:08.405000
# 1696588                          1 2018-10-11 19:57:13.367000
# 58320                            1 2018-10-12 12:42:14.517000
# 209055                           1 2018-10-12 13:36:29.711000
# 1452883                          1 2018-10-12 13:37:48.234000
# 1298909                          1 2018-10-12 13:42:22.746000
# 678955                           1 2018-10-12 13:42:37.155000
# 1455503                          1 2018-10-12 13:42:43.503000
# 697543                           1 2018-10-12 13:42:52.956000
# 796360                           1 2018-10-12 13:43:12.007000
# 11463                            1 2018-10-12 17:26:40.601000
# 453128                           1 2018-10-13 14:17:08.373000
# 1073184                          1 2018-10-13 14:37:05.341000
# 659654                           2 2018-10-13 14:43:34.084000
# 1710704                          3 2018-10-13 14:43:43.582000
# 1785161                          4 2018-10-13 14:45:02.627000
# 1025836                          5 2018-10-13 14:48:39.813000
# 1476196                          6 2018-10-13 14:48:57.407000
# 1016251                          7 2018-10-13 14:49:05.569000
# 1494932                          8 2018-10-13 14:49:26.396000
# 1336441                          1 2018-10-13 14:49:47.396000
# 1401710                          2 2018-10-14 10:36:26.064000
# 51237                            3 2018-10-14 10:36:44.611000
# 688678                           1 2018-10-14 10:39:40.333000
# 1127812                          1 2018-10-14 10:42:04.990000
# 1455610                          2 2018-10-14 10:51:42.728000
# 115683                           1 2018-10-14 10:55:48.529000
#
#         assessment_action_start_ts  guest_user_id  \
# 584798     2019-03-31 15:42:52.467            NaN
# 612727     2019-03-31 15:42:52.467            NaN
# 1232519    2019-03-31 15:42:52.467            NaN
# 903484     2019-03-31 15:42:52.467            NaN
# 528516     2019-03-31 15:42:52.467            NaN
# 1523168    2019-03-31 15:42:52.467            NaN
# 416441     2019-03-31 16:14:50.092            NaN
# 1355256    2019-03-31 16:14:50.092            NaN
# 1392760    2019-03-31 16:56:38.736            NaN
# 70251      2019-03-31 16:56:38.736            NaN
# 545356     2019-03-31 17:20:18.772            NaN
# 1455707    2019-03-31 17:22:24.870            NaN
# 1127919    2019-03-31 17:24:56.923            NaN
# 731761     2019-03-31 17:35:18.101            NaN
# 1070677    2019-03-31 17:35:18.101            NaN
# 1436664    2019-03-31 17:37:32.668            NaN
# 1352875    2019-04-01 10:35:37.044            NaN
# 1390242    2019-04-01 10:35:50.906            NaN
# 95635      2019-04-01 14:02:33.664            NaN
# 217359     2019-04-02 19:10:19.584            NaN
# 1530758    2019-04-02 19:55:08.572            NaN
# 864141     2019-04-02 19:55:22.154            NaN
# 996993     2019-04-02 19:58:27.243            NaN
# 1344914    2019-04-02 19:58:32.283            NaN
# 340763     2019-04-02 19:59:42.452            NaN
# 856271     2019-01-18 06:18:37.723            NaN
# 303408     2019-01-18 06:18:37.723            NaN
# 453070     2019-01-18 06:18:37.723            NaN
# 1457254    2019-01-18 06:18:37.723            NaN
# 1588202    2019-01-18 06:18:37.723            NaN
# ...                            ...            ...
# 1489673    2019-11-02 12:07:11.115            NaN
# 1059174    2019-11-02 12:07:38.025            NaN
# 1497540    2018-10-09 14:39:05.000            NaN
# 613013     2018-10-11 19:57:08.000            NaN
# 1696588    2018-10-11 19:57:13.000            NaN
# 58320      2018-10-12 12:42:14.000            NaN
# 209055     2018-10-12 13:36:29.000            NaN
# 1452883    2018-10-12 13:37:48.000            NaN
# 1298909    2018-10-12 13:42:22.000            NaN
# 678955     2018-10-12 13:42:37.000            NaN
# 1455503    2018-10-12 13:42:43.000            NaN
# 697543     2018-10-12 13:42:52.000            NaN
# 796360     2018-10-12 13:43:12.000            NaN
# 11463      2018-10-12 17:26:40.000            NaN
# 453128     2018-10-13 14:17:08.000            NaN
# 1073184    2018-10-13 14:37:05.000            NaN
# 659654     2018-10-13 14:37:05.000            NaN
# 1710704    2018-10-13 14:37:05.000            NaN
# 1785161    2018-10-13 14:37:05.000            NaN
# 1025836    2018-10-13 14:37:05.000            NaN
# 1476196    2018-10-13 14:37:05.000            NaN
# 1016251    2018-10-13 14:37:05.000            NaN
# 1494932    2018-10-13 14:37:05.000            NaN
# 1336441    2018-10-13 14:49:47.000            NaN
# 1401710    2018-10-13 14:49:47.000            NaN
# 51237      2018-10-13 14:49:47.000            NaN
# 688678     2018-10-14 10:39:40.000            NaN
# 1127812    2018-10-14 10:42:04.000            NaN
# 1455610    2018-10-14 10:42:04.000            NaN
# 115683     2018-10-14 10:55:48.000            NaN
#
#                                       hse_user_id
# 584798   0004f43a2fc120d733dd3dc6783079fca531f815
# 612727   0004f43a2fc120d733dd3dc6783079fca531f815
# 1232519  0004f43a2fc120d733dd3dc6783079fca531f815
# 903484   0004f43a2fc120d733dd3dc6783079fca531f815
# 528516   0004f43a2fc120d733dd3dc6783079fca531f815
# 1523168  0004f43a2fc120d733dd3dc6783079fca531f815
# 416441   0004f43a2fc120d733dd3dc6783079fca531f815
# 1355256  0004f43a2fc120d733dd3dc6783079fca531f815
# 1392760  0004f43a2fc120d733dd3dc6783079fca531f815
# 70251    0004f43a2fc120d733dd3dc6783079fca531f815
# 545356   0004f43a2fc120d733dd3dc6783079fca531f815
# 1455707  0004f43a2fc120d733dd3dc6783079fca531f815
# 1127919  0004f43a2fc120d733dd3dc6783079fca531f815
# 731761   0004f43a2fc120d733dd3dc6783079fca531f815
# 1070677  0004f43a2fc120d733dd3dc6783079fca531f815
# 1436664  0004f43a2fc120d733dd3dc6783079fca531f815
# 1352875  0004f43a2fc120d733dd3dc6783079fca531f815
# 1390242  0004f43a2fc120d733dd3dc6783079fca531f815
# 95635    0004f43a2fc120d733dd3dc6783079fca531f815
# 217359   0004f43a2fc120d733dd3dc6783079fca531f815
# 1530758  0004f43a2fc120d733dd3dc6783079fca531f815
# 864141   0004f43a2fc120d733dd3dc6783079fca531f815
# 996993   0004f43a2fc120d733dd3dc6783079fca531f815
# 1344914  0004f43a2fc120d733dd3dc6783079fca531f815
# 340763   0004f43a2fc120d733dd3dc6783079fca531f815
# 856271   0006df74eb925d86ed0f7d5934091d371acfd36c
# 303408   0006df74eb925d86ed0f7d5934091d371acfd36c
# 453070   0006df74eb925d86ed0f7d5934091d371acfd36c
# 1457254  0006df74eb925d86ed0f7d5934091d371acfd36c
# 1588202  0006df74eb925d86ed0f7d5934091d371acfd36c
# ...                                           ...
# 1489673  fffd330468cbcbd0c9fd560b9185ac3b0da375db
# 1059174  fffd330468cbcbd0c9fd560b9185ac3b0da375db
# 1497540  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 613013   ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1696588  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 58320    ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 209055   ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1452883  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1298909  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 678955   ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1455503  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 697543   ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 796360   ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 11463    ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 453128   ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1073184  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 659654   ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1710704  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1785161  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1025836  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1476196  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1016251  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1494932  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1336441  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1401710  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 51237    ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 688678   ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1127812  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 1455610  ffff6d47fbe86278661bc45d7f784bbeafce64cf
# 115683   ffff6d47fbe86278661bc45d7f784bbeafce64cf
#
# [1800135 rows x 10 columns]

# %%
# парсинг csv одного курса из архива в DataFrame
def parse_structure():
    df['course_id'] = df.apply(lambda x: x[1][:x[1].find('+type@chapter')].replace('block-v1:', ''), axis=1)
    df['chapter_id'] = df.apply(lambda x: x[1].replace(f'block-v1:{x["course_id"]}+type@chapter+block@', ''), axis=1) 
    df['sequential_id'] = df.apply(lambda x: x[2].replace(f'block-v1:{x["course_id"]}+type@sequential+block@', ''), axis=1)
    df['vertical_id'] = df.apply(lambda x: x[3].replace(f'block-v1:{x["course_id"]}+type@vertical+block@', ''), axis=1)
    
    df['item_type'] = df.apply(lambda x: x[4].replace(f'block-v1:{x["course_id"]}+type@', ''), axis=1)
    df['item_type'] = df.apply(lambda x: x['item_type'][:x['item_type'].find('+')], axis=1)
                                                      
    df['item_id'] = df.apply(lambda x: x[4].replace(f'block-v1:{x["course_id"]}+type@{x["item_type"]}+block@', ''), axis=1)
                                                    
    df[['chapter_name', 'sequential_name', 'vertical_name', 'item_name']] = df[[5, 6, 7, 8]]

# %% [markdown]
# ### Функции-обертки для обращений к БД

# %%
def find_course(course_extid):
    cursor.callproc("openedu_structure.find_course", [course_extid,])
    return cursor.fetchone()[0]

# %%
def add_chapter(course_id, chapter_extid, chapter_name):
    cursor.callproc("openedu_structure.add_chapter", [course_id, chapter_extid, chapter_name,])
    return cursor.fetchone()[0]

# %%
def add_sequential(chapter_id, sequential_extid, sequential_name):
    cursor.callproc("openedu_structure.add_sequential", [chapter_id, sequential_extid, sequential_name,])
    return cursor.fetchone()[0]

# %%
def add_vertical(sequential_id, vertical_extid, vertical_name):
    cursor.callproc("openedu_structure.add_vertical", [sequential_id, vertical_extid, vertical_name,])
    return cursor.fetchone()[0]

# %%
def add_item(vertical_id, item_extid, item_type, item_name):
    cursor.callproc("openedu_structure.add_item", [vertical_id, item_extid, item_type, item_name,])
    return cursor.fetchone()[0]

# %% [markdown]
# ### Загрузка курса в БД

# %%
def load_course_to_db():
    conn = psycopg2.connect(dbname='test', user='postgres', 
                        password='pg215', host='VM-AS494')
    cursor = conn.cursor()

    course_extid = 0
    chapter_extid = 0
    sequential_extid = 0
    vertical_extid = 0
    item_extid = 0

    for row in df.iterrows():
        if course_extid != row[1]['course_id']:
            course_extid = row[1]['course_id']
            course_id = find_course(course_extid)
            if not course_id:
                continue

        if chapter_extid != row[1]['chapter_id']:
            chapter_extid = row[1]['chapter_id']
            chapter_id = add_chapter(course_id, chapter_extid, row[1]['chapter_name'])

        if sequential_extid != row[1]['sequential_id']:
            sequential_extid = row[1]['sequential_id']
            sequential_id = add_sequential(chapter_id, sequential_extid, row[1]['sequential_name'])

        if vertical_extid != row[1]['vertical_id']:
            vertical_extid = row[1]['vertical_id']
            vertical_id = add_vertical(sequential_id, vertical_extid, row[1]['vertical_name'])

        if item_extid != row[1]['item_id']:
            item_extid = row[1]['item_id']
            #print(vertical_id, item_extid, row[1]['item_type'], row[1]['item_name']) 
            add_item(vertical_id, item_extid, row[1]['item_type'], row[1]['item_name'])    

    
    conn.commit()
    cursor.close()
    return course_id, course_extid

# %%
# подключение к БД
conn = psycopg2.connect(dbname='test', user='postgres', 
                        password='pg215', host='VM-AS494')
cursor = conn.cursor()

# %% [markdown]
# ## Основной цикл загрузки

# %%
with open('qq.txt', 'r', encoding='utf-8') as g:
    for line in g:
        print(f'Обрабатывается {line}')
        fname = load_from_url(line)
        
        with gzip.open(fname) as f:
            df = pd.read_csv(f, sep=';', header=None)
        
        parse_structure()
        print(f'Размер датафрейма к загрузке {df.shape}')
        
        print(f'Загружен в БД контент для курса  {load_course_to_db()}')
# Out:
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_ECONOM_spring_2019.csv.gz
#
# (120, 19)
# (133, 'hse+ECONOM+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_EXACTS_spring_2019.csv.gz
#
# (209, 19)
# (159, 'hse+EXACTS+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_FIL_spring_2019.csv.gz
#
# (274, 19)
# (173, 'hse+FIL+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_FORLANG_spring_2019.csv.gz
#
# (226, 19)
# (227, 'hse+FORLANG+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_FUNDLAW_spring_2019.csv.gz
#
# (97, 19)
# (234, 'hse+FUNDLAW+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_LABLAW_spring_2019.csv.gz
#
# (219, 19)
# (305, 'hse+LABLAW+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_MACROEC_spring_2019.csv.gz
#
# (139, 19)
# (335, 'hse+MACROEC+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_AIPP_spring_2019.csv.gz
#
# (93, 19)
# (9, 'hse+AIPP+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_COMPOL_spring_2019.csv.gz
#
# (148, 19)
# (41, 'hse+COMPOL+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_DATPRO_spring_2019.csv.gz
#
# (156, 19)
# (100, 'hse+DATPRO+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_ECPSY_spring_2019.csv.gz
#
# (69, 19)
# (141, 'hse+ECPSY+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_ECSOC_spring_2019.csv.gz
#
# (133, 19)
# (151, 'hse+ECSOC+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_FINMARKAN_spring_2019.csv.gz
#
# (118, 19)
# (201, 'hse+FINMARKAN+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_FINTECH_spring_2019.csv.gz
#
# (73, 19)
# (222, 'hse+FINTECH+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_INTMODPOL_spring_2019.csv.gz
#
# (112, 19)
# (285, 'hse+INTMODPOL+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_MARKMAN_spring_2019.csv.gz
#
# (82, 19)
# (367, 'hse+MARKMAN+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_MODSYS_spring_2019.csv.gz
#
# (101, 19)
# (416, 'hse+MODSYS+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_ORGBH_spring_2019.csv.gz
#
# (114, 19)
# (447, 'hse+ORGBH+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_PROTECT_spring_2019.csv.gz
#
# (91, 19)
# (508, 'hse+PROTECT+spring_2019')
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_STATAN_spring_2019.csv.gz
# (91, 19)
# (604, 'hse+STATAN+spring_2019')

# %%
conn.commit()
cursor.close()

# %%
features = ['course_id', 'chapter_id', 'chapter_name', 'sequential_id', 'sequential_name', 
            'vertical_id', 'vertical_name', 'item_type', 'item_id',  'item_name']
df[features].head()
# Out:
#                 course_id                        chapter_id  \
# 0  hse+DATPRO+spring_2019  8411723edf2f4d8cb6b130fb8023a26d
# 1  hse+DATPRO+spring_2019  911bd2c030644cc9841a2950b62489c0
# 2  hse+DATPRO+spring_2019  911bd2c030644cc9841a2950b62489c0
# 3  hse+DATPRO+spring_2019  911bd2c030644cc9841a2950b62489c0
# 4  hse+DATPRO+spring_2019  911bd2c030644cc9841a2950b62489c0
#
#                                         chapter_name  \
# 0                                            О Вышке
# 1  Тема 1. Основы информационной безопасности. Ос...
# 2  Тема 1. Основы информационной безопасности. Ос...
# 3  Тема 1. Основы информационной безопасности. Ос...
# 4  Тема 1. Основы информационной безопасности. Ос...
#
#                       sequential_id sequential_name  \
# 0  b74b1284929046d2b280f3c560f0e896     Промо-ролик
# 1  da6736e32aae4ac6922f6c55129d312f        Лекция 1
# 2  da6736e32aae4ac6922f6c55129d312f        Лекция 1
# 3  da6736e32aae4ac6922f6c55129d312f        Лекция 1
# 4  da6736e32aae4ac6922f6c55129d312f        Лекция 1
#
#                         vertical_id           vertical_name item_type  \
# 0  e444e0cf02854ed9b516481d39f9a342             Промо-ролик     video
# 1  f27a9e3ace954d9a9838ee229f116f94      Понятие информации     video
# 2  dd37a044619949568f9ae7323be7850d     Доступ к информации     video
# 3  f6b6aa6909cd40abbc74e2fd1845d549  Информационные системы     video
# 4  f915b0bf93c24c859d741e11993375f8    Обработка информации     video
#
#                             item_id               item_name
# 0  5b50ca94e2774d6f83da03543e39bf50             Видео о ВШЭ
# 1  261019e7ca7d40cabf469069dbef052c      Понятие информации
# 2  d1efc98f8244445f9d011479366f9fb2     Доступ к информации
# 3  19a06eb43b0f461e88ac12340ed9cb54  Информационные системы
# 4  94ef7b162a3442a19eb4c3dd436afc45    Обработка информации

# %%
conn = psycopg2.connect(dbname='test', user='postgres', 
                        password='pg215', host='VM-AS494')
cursor = conn.cursor()

# %%
copy_sql = """
  copy open_edu_course (id, name, ext_id)
  from stdin with
    csv
    header
    delimiter as ';'
"""
from_csv = 'course_for_load1.csv'
with open(from_csv, 'r') as f:
  cursor.copy_expert(sql=copy_sql, file=f)
  conn.commit()
  cursor.close()

# %%
# ?cursor.copy_expert

# %%
conn.commit()

# %%
cursor.execute("SELECT * FROM openedu_structure.course where ext_id like '%FUNDLAW%'")

# %%
for row in cursor:
    print(row)
# Out:
# (230, '(DEMO)Основы права', 'hse+FUNDLAW+DEMO', None)
# (231, '(2018-2)Основы права', 'hse+FUNDLAW+fall_2018', None)
# (232, 'Основы права', 'hse+FUNDLAW+fall_2019', None)
# (233, 'Основы права', 'hse+FUNDLAW+fall_2019_dvfu', None)
# (234, '(2019-1)Основы права', 'hse+FUNDLAW+spring_2019', None)
# (235, 'Основы права', 'hse+FUNDLAW+spring_2020', None)
# (236, '(2018-2)Основы права', 'hse+FUNDLAW+stud_fall_2018', None)
# (237, 'Основы права', 'hse+FUNDLAW+stud_fall_2019', None)
# (238, 'Основы права', 'hse+FUNDLAW+workshop_adaptive', None)

# %%
from psycopg2 import sql

# %%
columns = ('country_name_ru', 'airport_name_ru', 'city_code')
stmt = sql.SQL('SELECT {} FROM {} LIMIT 5').format(
            sql.SQL(',').join(map(sql.Identifier, columns)),
            sql.Identifier('airport')
        )

# %%
values = [
        (3, 'однажды в ... ;;;'),
        (4, 'хэлло, товарищи!'),
    ]

# %%
insert = sql.SQL('INSERT INTO test_table (id, name) VALUES {}').format(
        sql.SQL(',').join(map(sql.Literal, values))
    )

# %%
cursor.execute(insert)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# <ipython-input-32-88967c0974e3> in <module>
# ----> 1 cursor.execute(insert)
#
# UniqueViolation: ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "test_table_pkey"
# DETAIL:  Ключ "(id)=(3)" уже существует.

# %%
insert
# Out:
# Composed([SQL('INSERT INTO test_table (id, name) VALUES '), Composed([Literal((3, 'однажды в ... ;;;')), SQL(','), Literal((4, 'хэлло, товарищи!'))])])

# %%
conn.commit()  # или надо использовать conn.autocommit = True

# %% [markdown]
# ### На память: для перезагрузки конфига в  psql запустить select pg_reload_conf()

# %% [markdown]
# ## Скачивание по массиву ссылок

# %%
# Out:
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_ECONOM_spring_2019.csv.gz
#
# structure_hse_ECONOM_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_EXACTS_spring_2019.csv.gz
#
# structure_hse_EXACTS_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_FIL_spring_2019.csv.gz
#
# structure_hse_FIL_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_FORLANG_spring_2019.csv.gz
#
# structure_hse_FORLANG_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_FUNDLAW_spring_2019.csv.gz
#
# structure_hse_FUNDLAW_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_LABLAW_spring_2019.csv.gz
#
# structure_hse_LABLAW_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137e/structure_hse_MACROEC_spring_2019.csv.gz
#
# structure_hse_MACROEC_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_AIPP_spring_2019.csv.gz
#
# structure_hse_AIPP_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_COMPOL_spring_2019.csv.gz
#
# structure_hse_COMPOL_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_DATPRO_spring_2019.csv.gz
#
# structure_hse_DATPRO_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_ECPSY_spring_2019.csv.gz
#
# structure_hse_ECPSY_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_ECSOC_spring_2019.csv.gz
#
# structure_hse_ECSOC_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_FINMARKAN_spring_2019.csv.gz
#
# structure_hse_FINMARKAN_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_FINTECH_spring_2019.csv.gz
#
# structure_hse_FINTECH_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_INTMODPOL_spring_2019.csv.gz
#
# structure_hse_INTMODPOL_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_MARKMAN_spring_2019.csv.gz
#
# structure_hse_MARKMAN_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_MODSYS_spring_2019.csv.gz
#
# structure_hse_MODSYS_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_ORGBH_spring_2019.csv.gz
#
# structure_hse_ORGBH_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_PROTECT_spring_2019.csv.gz
#
# structure_hse_PROTECT_spring_2019.csv.gz
# https://207918.selcdn.ru/jCJ5Ef1pLDebKtwW/SUPPORT-1137d/structure_hse_STATAN_spring_2019.csv.gz
# structure_hse_STATAN_spring_2019.csv.gz

# %%
import gzip

# %%
# Out:
#    0                                                  1  \
# 0  0  block-v1:hse+ECPSY+spring_2019+type@chapter+bl...
# 1  1  block-v1:hse+ECPSY+spring_2019+type@chapter+bl...
# 2  2  block-v1:hse+ECPSY+spring_2019+type@chapter+bl...
# 3  3  block-v1:hse+ECPSY+spring_2019+type@chapter+bl...
# 4  4  block-v1:hse+ECPSY+spring_2019+type@chapter+bl...
#
#                                                    2  \
# 0  block-v1:hse+ECPSY+spring_2019+type@sequential...
# 1  block-v1:hse+ECPSY+spring_2019+type@sequential...
# 2  block-v1:hse+ECPSY+spring_2019+type@sequential...
# 3  block-v1:hse+ECPSY+spring_2019+type@sequential...
# 4  block-v1:hse+ECPSY+spring_2019+type@sequential...
#
#                                                    3  \
# 0  block-v1:hse+ECPSY+spring_2019+type@vertical+b...
# 1  block-v1:hse+ECPSY+spring_2019+type@vertical+b...
# 2  block-v1:hse+ECPSY+spring_2019+type@vertical+b...
# 3  block-v1:hse+ECPSY+spring_2019+type@vertical+b...
# 4  block-v1:hse+ECPSY+spring_2019+type@vertical+b...
#
#                                                    4  \
# 0  block-v1:hse+ECPSY+spring_2019+type@video+bloc...
# 1  block-v1:hse+ECPSY+spring_2019+type@video+bloc...
# 2  block-v1:hse+ECPSY+spring_2019+type@video+bloc...
# 3  block-v1:hse+ECPSY+spring_2019+type@video+bloc...
# 4  block-v1:hse+ECPSY+spring_2019+type@video+bloc...
#
#                                     5            6  \
# 0                             О Вышке  Промо-ролик
# 1  Неделя 1: Экономическая психология     Лекция 1
# 2  Неделя 1: Экономическая психология     Лекция 1
# 3  Неделя 1: Экономическая психология     Лекция 1
# 4  Неделя 1: Экономическая психология     Лекция 1
#
#                                            7                                 8
# 0                                Промо-ролик                       Промо-ролик
# 1  Предмет экономической психологии. Часть 1  Предмет экономической психологии
# 2  Предмет экономической психологии. Часть 2  Предмет экономической психологии
# 3           История экономической психологии  История экономической психологии
# 4            Методы экономической психологии   Методы экономической психологии

# %%
parse_structure()

# %%
df
# Out:
#        assessment_question_id assessment_question_base_id  \
# 0    NFkcnnrUEeetkBKcF7Gx4A@2      NFkcnnrUEeetkBKcF7Gx4A
# 1    w_yYQI8xEeeCnhKCj4fcOA@3      w_yYQI8xEeeCnhKCj4fcOA
# 2    -aErO0rnEeiInQq_9aGGQg@1      -aErO0rnEeiInQq_9aGGQg
# 3    7Aket543EeevgwpFUW6DoA@1      7Aket543EeevgwpFUW6DoA
# 4    EkL0tHnsEeeh7wqtJBDcag@2      EkL0tHnsEeeh7wqtJBDcag
# 5    825BdkrnEeip3wrcpPrs7A@1      825BdkrnEeip3wrcpPrs7A
# 6    EkL0tHnsEeeh7wqtJBDcag@1      EkL0tHnsEeeh7wqtJBDcag
# 7    NFgxsnrUEeexdQ4iFFMrvA@2      NFgxsnrUEeexdQ4iFFMrvA
# 8    bhgcUnoiEeezGQp6YRZP7g@4      bhgcUnoiEeezGQp6YRZP7g
# 9    fBEL1KFlEeesZAoGx9lBJA@2      fBEL1KFlEeesZAoGx9lBJA
# 10   yCt3d5pcEeeKDBL2UWdiaA@2      yCt3d5pcEeeKDBL2UWdiaA
# 11   -dBR9krnEeip3wrcpPrs7A@1      -dBR9krnEeip3wrcpPrs7A
# 12   0bVq65pTEee17g5AYPYOPA@2      0bVq65pTEee17g5AYPYOPA
# 13   EkCqqHnsEeeUgxIgXhmlDg@1      EkCqqHnsEeeUgxIgXhmlDg
# 14   U9PTRIBBEeesHwqJufKBxA@5      U9PTRIBBEeesHwqJufKBxA
# 15   -Hesm3UIEeeNphJ8fYldeg@5      -Hesm3UIEeeNphJ8fYldeg
# 16   -e3EVkrnEei1QRIajygUqg@1      -e3EVkrnEei1QRIajygUqg
# 17   FEhcTJMHEeek-BJjMQJUpg@1      FEhcTJMHEeek-BJjMQJUpg
# 18   -J3FlkrnEeip3wrcpPrs7A@1      -J3FlkrnEeip3wrcpPrs7A
# 19   HGS1rXn1EeelpgpYPAO2Og@1      HGS1rXn1EeelpgpYPAO2Og
# 20   HGUD_Hn1Eee1JA5jQfm2lg@3      HGUD_Hn1Eee1JA5jQfm2lg
# 21   Z1ZqyprJEee5_BJx0tzyHg@3      Z1ZqyprJEee5_BJx0tzyHg
# 22   9N5MW0rnEei9qRLizQHdHA@1      9N5MW0rnEei9qRLizQHdHA
# 23   9BKwQ5rQEeea8A6GzH-6CA@2      9BKwQ5rQEeea8A6GzH-6CA
# 24   nzaS-Hn9EeezGQp6YRZP7g@1      nzaS-Hn9EeezGQp6YRZP7g
# 25   x42XhdHEEeeYWAqTi5yRnA@2      x42XhdHEEeeYWAqTi5yRnA
# 26   9FMjLErnEeiS4gqbWEoieg@1      9FMjLErnEeiS4gqbWEoieg
# 27   w_xxGI8xEeebJRLjDvDWqA@3      w_xxGI8xEeebJRLjDvDWqA
# 28   ymwDeKjbEeeyRQ49DL8F0A@2      ymwDeKjbEeeyRQ49DL8F0A
# 29   -CQoo0rnEeiwfxI_WsJuSA@1      -CQoo0rnEeiwfxI_WsJuSA
# ..                        ...                         ...
# 439  mQhBe6gpEeeQdw6F9o9tlA@3      mQhBe6gpEeeQdw6F9o9tlA
# 440  7Aipn543EeeQuhLpsXgReg@1      7Aipn543EeeQuhLpsXgReg
# 441  8Ainz0rnEeiInQq_9aGGQg@1      8Ainz0rnEeiInQq_9aGGQg
# 442  HGTdZ3n1Eeeu2g6_iv_hoA@1      HGTdZ3n1Eeeu2g6_iv_hoA
# 443  U9PTRIBBEeesHwqJufKBxA@2      U9PTRIBBEeesHwqJufKBxA
# 444  1pV2FJrKEeeR4Aq3QaMBjg@2      1pV2FJrKEeeR4Aq3QaMBjg
# 445  fBEL1KFlEeesZAoGx9lBJA@4      fBEL1KFlEeesZAoGx9lBJA
# 446  w_xxl48xEeea2A7iqf1DKg@2      w_xxl48xEeea2A7iqf1DKg
# 447  U9JMoIBBEee2BBInzAelbA@3      U9JMoIBBEee2BBInzAelbA
# 448  m4WSk6HuEeeyGBLD6ftc7g@2      m4WSk6HuEeeyGBLD6ftc7g
# 449  -DR7_krnEei9qRLizQHdHA@1      -DR7_krnEei9qRLizQHdHA
# 450  9lwSWUrnEei9qRLizQHdHA@1      9lwSWUrnEei9qRLizQHdHA
# 451  NFmR0XrUEeetkBKcF7Gx4A@2      NFmR0XrUEeetkBKcF7Gx4A
# 452  nzaSb3n9EeetkBKcF7Gx4A@2      nzaSb3n9EeetkBKcF7Gx4A
# 453  8UjwkErnEeiS7g6V16twWA@1      8UjwkErnEeiS7g6V16twWA
# 454  9yHTkUrnEeiS7g6V16twWA@1      9yHTkUrnEeiS7g6V16twWA
# 455  L8qxbprPEeeTjA6Q_TkuOA@2      L8qxbprPEeeTjA6Q_TkuOA
# 456  8GRcdUrnEei0EAo_peGsKA@1      8GRcdUrnEei0EAo_peGsKA
# 457  9XcxPUrnEeiKug5KaWnaxg@1      9XcxPUrnEeiKug5KaWnaxg
# 458  8gCA60rnEeiDyBKDsMU63g@1      8gCA60rnEeiDyBKDsMU63g
# 459  HmJZ_JpcEeeE3RJ9kInp-g@2      HmJZ_JpcEeeE3RJ9kInp-g
# 460  U9dVdIBBEeeYCw48mV6YeA@2      U9dVdIBBEeeYCw48mV6YeA
# 461  9EQvh0rnEei13w4JAorB3g@1      9EQvh0rnEei13w4JAorB3g
# 462  cXjec3nOEeeh7wqtJBDcag@3      cXjec3nOEeeh7wqtJBDcag
# 463  nza6Cnn9EeezGQp6YRZP7g@3      nza6Cnn9EeezGQp6YRZP7g
# 464  -EF0o0rnEeiGLA75fJqmTg@1      -EF0o0rnEeiGLA75fJqmTg
# 465  bhenG3oiEeeR8BJuFPFhxA@2      bhenG3oiEeeR8BJuFPFhxA
# 466  9ZO5yUrnEeiInQq_9aGGQg@1      9ZO5yUrnEeiInQq_9aGGQg
# 467  cXkFjXnOEeezGQp6YRZP7g@3      cXkFjXnOEeezGQp6YRZP7g
# 468  EP7yY6hGEeelxApGzJus9A@2      EP7yY6hGEeelxApGzJus9A
#
#      assessment_question_version  assessment_question_type_id  \
# 0                              2                            5
# 1                              3                            1
# 2                              1                            1
# 3                              1                            5
# 4                              2                            1
# 5                              1                            1
# 6                              1                            1
# 7                              2                            1
# 8                              4                            8
# 9                              2                            5
# 10                             2                            5
# 11                             1                            5
# 12                             2                            1
# 13                             1                            5
# 14                             5                            5
# 15                             5                            1
# 16                             1                            1
# 17                             1                            5
# 18                             1                            9
# 19                             1                            5
# 20                             3                            5
# 21                             3                            1
# 22                             1                            5
# 23                             2                            1
# 24                             1                            5
# 25                             2                            3
# 26                             1                            5
# 27                             3                            1
# 28                             2                            5
# 29                             1                            5
# ..                           ...                          ...
# 439                            3                            1
# 440                            1                            5
# 441                            1                            1
# 442                            1                            5
# 443                            2                            5
# 444                            2                            5
# 445                            4                            5
# 446                            2                            5
# 447                            3                            5
# 448                            2                            1
# 449                            1                            1
# 450                            1                            5
# 451                            2                            5
# 452                            2                            1
# 453                            1                            5
# 454                            1                            9
# 455                            2                            5
# 456                            1                            1
# 457                            1                            1
# 458                            1                            5
# 459                            2                            5
# 460                            2                            5
# 461                            1                            5
# 462                            3                            1
# 463                            3                            1
# 464                            1                            1
# 465                            2                            1
# 466                            1                            1
# 467                            3                            1
# 468                            2                            5
#
#                             assessment_question_prompt  \
# 0    {"typeName":"cml","definition":{"dtdId":"asses...
# 1    {"typeName":"cml","definition":{"dtdId":"asses...
# 2    {"typeName":"cml","definition":{"dtdId":"asses...
# 3    {"typeName":"cml","definition":{"dtdId":"asses...
# 4    {"typeName":"cml","definition":{"dtdId":"asses...
# 5    {"typeName":"cml","definition":{"dtdId":"asses...
# 6    {"typeName":"cml","definition":{"dtdId":"asses...
# 7    {"typeName":"cml","definition":{"dtdId":"asses...
# 8    {"typeName":"cml","definition":{"dtdId":"asses...
# 9    {"typeName":"cml","definition":{"dtdId":"asses...
# 10   {"typeName":"cml","definition":{"dtdId":"asses...
# 11   {"typeName":"cml","definition":{"dtdId":"asses...
# 12   {"typeName":"cml","definition":{"dtdId":"asses...
# 13   {"typeName":"cml","definition":{"dtdId":"asses...
# 14   {"typeName":"cml","definition":{"dtdId":"asses...
# 15   {"typeName":"cml","definition":{"dtdId":"asses...
# 16   {"typeName":"cml","definition":{"dtdId":"asses...
# 17   {"typeName":"cml","definition":{"dtdId":"asses...
# 18   {"typeName":"cml","definition":{"dtdId":"asses...
# 19   {"typeName":"cml","definition":{"dtdId":"asses...
# 20   {"typeName":"cml","definition":{"dtdId":"asses...
# 21   {"typeName":"cml","definition":{"dtdId":"asses...
# 22   {"typeName":"cml","definition":{"dtdId":"asses...
# 23   {"typeName":"cml","definition":{"dtdId":"asses...
# 24   {"typeName":"cml","definition":{"dtdId":"asses...
# 25   {"typeName":"cml","definition":{"dtdId":"asses...
# 26   {"typeName":"cml","definition":{"dtdId":"asses...
# 27   {"typeName":"cml","definition":{"dtdId":"asses...
# 28   {"typeName":"cml","definition":{"dtdId":"asses...
# 29   {"typeName":"cml","definition":{"dtdId":"asses...
# ..                                                 ...
# 439  {"typeName":"cml","definition":{"dtdId":"asses...
# 440  {"typeName":"cml","definition":{"dtdId":"asses...
# 441  {"typeName":"cml","definition":{"dtdId":"asses...
# 442  {"typeName":"cml","definition":{"dtdId":"asses...
# 443  {"typeName":"cml","definition":{"dtdId":"asses...
# 444  {"typeName":"cml","definition":{"dtdId":"asses...
# 445  {"typeName":"cml","definition":{"dtdId":"asses...
# 446  {"typeName":"cml","definition":{"dtdId":"asses...
# 447  {"typeName":"cml","definition":{"dtdId":"asses...
# 448  {"typeName":"cml","definition":{"dtdId":"asses...
# 449  {"typeName":"cml","definition":{"dtdId":"asses...
# 450  {"typeName":"cml","definition":{"dtdId":"asses...
# 451  {"typeName":"cml","definition":{"dtdId":"asses...
# 452  {"typeName":"cml","definition":{"dtdId":"asses...
# 453  {"typeName":"cml","definition":{"dtdId":"asses...
# 454  {"typeName":"cml","definition":{"dtdId":"asses...
# 455  {"typeName":"cml","definition":{"dtdId":"asses...
# 456  {"typeName":"cml","definition":{"dtdId":"asses...
# 457  {"typeName":"cml","definition":{"dtdId":"asses...
# 458  {"typeName":"cml","definition":{"dtdId":"asses...
# 459  {"typeName":"cml","definition":{"dtdId":"asses...
# 460  {"typeName":"cml","definition":{"dtdId":"asses...
# 461  {"typeName":"cml","definition":{"dtdId":"asses...
# 462  {"typeName":"cml","definition":{"dtdId":"asses...
# 463  {"typeName":"cml","definition":{"dtdId":"asses...
# 464  {"typeName":"cml","definition":{"dtdId":"asses...
# 465  {"typeName":"cml","definition":{"dtdId":"asses...
# 466  {"typeName":"cml","definition":{"dtdId":"asses...
# 467  {"typeName":"cml","definition":{"dtdId":"asses...
# 468  {"typeName":"cml","definition":{"dtdId":"asses...
#
#     assessment_question_update_ts
# 0         2017-08-06 20:50:40.598
# 1          2018-08-15 04:29:12.58
# 2         2018-04-28 13:28:02.083
# 3         2017-09-20 19:14:27.853
# 4         2018-08-15 02:56:08.717
# 5         2018-04-28 13:27:51.684
# 6         2017-08-05 14:40:48.375
# 7         2017-08-06 20:50:40.603
# 8         2017-10-24 22:57:08.773
# 9         2017-09-24 20:32:06.036
# 10        2017-09-15 21:30:21.161
# 11        2018-04-28 13:28:02.391
# 12        2017-09-15 20:28:21.274
# 13        2017-08-05 14:40:48.361
# 14        2018-08-12 17:45:58.678
# 15        2017-10-15 23:04:59.236
# 16        2018-04-28 13:28:02.586
# 17        2017-09-06 13:27:07.245
# 18        2018-04-28 13:28:00.382
# 19        2017-08-05 15:45:30.843
# 20         2017-10-16 12:55:12.42
# 21        2017-09-16 10:30:55.997
# 22        2018-04-28 13:27:54.095
# 23        2017-09-16 11:25:38.569
# 24        2017-08-05 16:46:26.296
# 25        2017-11-25 09:42:21.801
# 26        2018-04-28 13:27:53.182
# 27        2018-08-15 04:29:12.583
# 28        2017-10-04 08:33:53.048
# 29        2018-04-28 13:27:59.586
# ..                            ...
# 439       2017-10-04 08:00:47.935
# 440        2017-09-20 19:14:27.85
# 441       2018-04-28 13:27:45.987
# 442       2017-08-05 15:45:30.845
# 443       2017-10-03 23:43:00.017
# 444       2017-09-16 10:38:03.451
# 445       2017-12-14 13:52:23.977
# 446       2018-08-15 04:29:12.572
# 447       2017-10-15 23:04:59.237
# 448       2017-10-15 14:59:51.493
# 449       2018-04-28 13:27:59.692
# 450       2018-04-28 13:27:56.597
# 451       2017-09-17 09:10:09.886
# 452       2017-10-24 23:23:36.474
# 453       2018-04-28 13:27:48.085
# 454       2018-04-28 13:27:57.892
# 455       2017-09-16 11:08:31.351
# 456       2018-04-28 13:27:46.584
# 457       2018-04-28 13:27:55.097
# 458       2018-04-28 13:27:49.479
# 459       2017-09-15 21:25:38.992
# 460       2017-10-03 23:43:00.039
# 461       2018-04-28 13:27:53.192
# 462       2017-10-16 14:52:41.759
# 463       2018-04-26 19:53:58.756
# 464       2018-04-28 13:27:59.781
# 465       2017-08-06 19:05:16.384
# 466       2018-04-28 13:27:55.283
# 467       2017-10-15 16:27:45.393
# 468       2017-10-03 14:39:22.455
#
# [469 rows x 6 columns]

# %%
df.shift(3)
# Out:
#        assessment_question_id assessment_question_base_id  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3    NFkcnnrUEeetkBKcF7Gx4A@2      NFkcnnrUEeetkBKcF7Gx4A
# 4    w_yYQI8xEeeCnhKCj4fcOA@3      w_yYQI8xEeeCnhKCj4fcOA
# 5    -aErO0rnEeiInQq_9aGGQg@1      -aErO0rnEeiInQq_9aGGQg
# 6    7Aket543EeevgwpFUW6DoA@1      7Aket543EeevgwpFUW6DoA
# 7    EkL0tHnsEeeh7wqtJBDcag@2      EkL0tHnsEeeh7wqtJBDcag
# 8    825BdkrnEeip3wrcpPrs7A@1      825BdkrnEeip3wrcpPrs7A
# 9    EkL0tHnsEeeh7wqtJBDcag@1      EkL0tHnsEeeh7wqtJBDcag
# 10   NFgxsnrUEeexdQ4iFFMrvA@2      NFgxsnrUEeexdQ4iFFMrvA
# 11   bhgcUnoiEeezGQp6YRZP7g@4      bhgcUnoiEeezGQp6YRZP7g
# 12   fBEL1KFlEeesZAoGx9lBJA@2      fBEL1KFlEeesZAoGx9lBJA
# 13   yCt3d5pcEeeKDBL2UWdiaA@2      yCt3d5pcEeeKDBL2UWdiaA
# 14   -dBR9krnEeip3wrcpPrs7A@1      -dBR9krnEeip3wrcpPrs7A
# 15   0bVq65pTEee17g5AYPYOPA@2      0bVq65pTEee17g5AYPYOPA
# 16   EkCqqHnsEeeUgxIgXhmlDg@1      EkCqqHnsEeeUgxIgXhmlDg
# 17   U9PTRIBBEeesHwqJufKBxA@5      U9PTRIBBEeesHwqJufKBxA
# 18   -Hesm3UIEeeNphJ8fYldeg@5      -Hesm3UIEeeNphJ8fYldeg
# 19   -e3EVkrnEei1QRIajygUqg@1      -e3EVkrnEei1QRIajygUqg
# 20   FEhcTJMHEeek-BJjMQJUpg@1      FEhcTJMHEeek-BJjMQJUpg
# 21   -J3FlkrnEeip3wrcpPrs7A@1      -J3FlkrnEeip3wrcpPrs7A
# 22   HGS1rXn1EeelpgpYPAO2Og@1      HGS1rXn1EeelpgpYPAO2Og
# 23   HGUD_Hn1Eee1JA5jQfm2lg@3      HGUD_Hn1Eee1JA5jQfm2lg
# 24   Z1ZqyprJEee5_BJx0tzyHg@3      Z1ZqyprJEee5_BJx0tzyHg
# 25   9N5MW0rnEei9qRLizQHdHA@1      9N5MW0rnEei9qRLizQHdHA
# 26   9BKwQ5rQEeea8A6GzH-6CA@2      9BKwQ5rQEeea8A6GzH-6CA
# 27   nzaS-Hn9EeezGQp6YRZP7g@1      nzaS-Hn9EeezGQp6YRZP7g
# 28   x42XhdHEEeeYWAqTi5yRnA@2      x42XhdHEEeeYWAqTi5yRnA
# 29   9FMjLErnEeiS4gqbWEoieg@1      9FMjLErnEeiS4gqbWEoieg
# ..                        ...                         ...
# 439  HGS1q3n1EeelpgpYPAO2Og@5      HGS1q3n1EeelpgpYPAO2Og
# 440  0bVq65pTEee17g5AYPYOPA@3      0bVq65pTEee17g5AYPYOPA
# 441  9i1hc0rnEeiIVQ5O3tFWEg@1      9i1hc0rnEeiIVQ5O3tFWEg
# 442  mQhBe6gpEeeQdw6F9o9tlA@3      mQhBe6gpEeeQdw6F9o9tlA
# 443  7Aipn543EeeQuhLpsXgReg@1      7Aipn543EeeQuhLpsXgReg
# 444  8Ainz0rnEeiInQq_9aGGQg@1      8Ainz0rnEeiInQq_9aGGQg
# 445  HGTdZ3n1Eeeu2g6_iv_hoA@1      HGTdZ3n1Eeeu2g6_iv_hoA
# 446  U9PTRIBBEeesHwqJufKBxA@2      U9PTRIBBEeesHwqJufKBxA
# 447  1pV2FJrKEeeR4Aq3QaMBjg@2      1pV2FJrKEeeR4Aq3QaMBjg
# 448  fBEL1KFlEeesZAoGx9lBJA@4      fBEL1KFlEeesZAoGx9lBJA
# 449  w_xxl48xEeea2A7iqf1DKg@2      w_xxl48xEeea2A7iqf1DKg
# 450  U9JMoIBBEee2BBInzAelbA@3      U9JMoIBBEee2BBInzAelbA
# 451  m4WSk6HuEeeyGBLD6ftc7g@2      m4WSk6HuEeeyGBLD6ftc7g
# 452  -DR7_krnEei9qRLizQHdHA@1      -DR7_krnEei9qRLizQHdHA
# 453  9lwSWUrnEei9qRLizQHdHA@1      9lwSWUrnEei9qRLizQHdHA
# 454  NFmR0XrUEeetkBKcF7Gx4A@2      NFmR0XrUEeetkBKcF7Gx4A
# 455  nzaSb3n9EeetkBKcF7Gx4A@2      nzaSb3n9EeetkBKcF7Gx4A
# 456  8UjwkErnEeiS7g6V16twWA@1      8UjwkErnEeiS7g6V16twWA
# 457  9yHTkUrnEeiS7g6V16twWA@1      9yHTkUrnEeiS7g6V16twWA
# 458  L8qxbprPEeeTjA6Q_TkuOA@2      L8qxbprPEeeTjA6Q_TkuOA
# 459  8GRcdUrnEei0EAo_peGsKA@1      8GRcdUrnEei0EAo_peGsKA
# 460  9XcxPUrnEeiKug5KaWnaxg@1      9XcxPUrnEeiKug5KaWnaxg
# 461  8gCA60rnEeiDyBKDsMU63g@1      8gCA60rnEeiDyBKDsMU63g
# 462  HmJZ_JpcEeeE3RJ9kInp-g@2      HmJZ_JpcEeeE3RJ9kInp-g
# 463  U9dVdIBBEeeYCw48mV6YeA@2      U9dVdIBBEeeYCw48mV6YeA
# 464  9EQvh0rnEei13w4JAorB3g@1      9EQvh0rnEei13w4JAorB3g
# 465  cXjec3nOEeeh7wqtJBDcag@3      cXjec3nOEeeh7wqtJBDcag
# 466  nza6Cnn9EeezGQp6YRZP7g@3      nza6Cnn9EeezGQp6YRZP7g
# 467  -EF0o0rnEeiGLA75fJqmTg@1      -EF0o0rnEeiGLA75fJqmTg
# 468  bhenG3oiEeeR8BJuFPFhxA@2      bhenG3oiEeeR8BJuFPFhxA
#
#      assessment_question_version  assessment_question_type_id  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            2.0                          5.0
# 4                            3.0                          1.0
# 5                            1.0                          1.0
# 6                            1.0                          5.0
# 7                            2.0                          1.0
# 8                            1.0                          1.0
# 9                            1.0                          1.0
# 10                           2.0                          1.0
# 11                           4.0                          8.0
# 12                           2.0                          5.0
# 13                           2.0                          5.0
# 14                           1.0                          5.0
# 15                           2.0                          1.0
# 16                           1.0                          5.0
# 17                           5.0                          5.0
# 18                           5.0                          1.0
# 19                           1.0                          1.0
# 20                           1.0                          5.0
# 21                           1.0                          9.0
# 22                           1.0                          5.0
# 23                           3.0                          5.0
# 24                           3.0                          1.0
# 25                           1.0                          5.0
# 26                           2.0                          1.0
# 27                           1.0                          5.0
# 28                           2.0                          3.0
# 29                           1.0                          5.0
# ..                           ...                          ...
# 439                          5.0                          5.0
# 440                          3.0                          1.0
# 441                          1.0                          9.0
# 442                          3.0                          1.0
# 443                          1.0                          5.0
# 444                          1.0                          1.0
# 445                          1.0                          5.0
# 446                          2.0                          5.0
# 447                          2.0                          5.0
# 448                          4.0                          5.0
# 449                          2.0                          5.0
# 450                          3.0                          5.0
# 451                          2.0                          1.0
# 452                          1.0                          1.0
# 453                          1.0                          5.0
# 454                          2.0                          5.0
# 455                          2.0                          1.0
# 456                          1.0                          5.0
# 457                          1.0                          9.0
# 458                          2.0                          5.0
# 459                          1.0                          1.0
# 460                          1.0                          1.0
# 461                          1.0                          5.0
# 462                          2.0                          5.0
# 463                          2.0                          5.0
# 464                          1.0                          5.0
# 465                          3.0                          1.0
# 466                          3.0                          1.0
# 467                          1.0                          1.0
# 468                          2.0                          1.0
#
#                             assessment_question_prompt  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    {"typeName":"cml","definition":{"dtdId":"asses...
# 4    {"typeName":"cml","definition":{"dtdId":"asses...
# 5    {"typeName":"cml","definition":{"dtdId":"asses...
# 6    {"typeName":"cml","definition":{"dtdId":"asses...
# 7    {"typeName":"cml","definition":{"dtdId":"asses...
# 8    {"typeName":"cml","definition":{"dtdId":"asses...
# 9    {"typeName":"cml","definition":{"dtdId":"asses...
# 10   {"typeName":"cml","definition":{"dtdId":"asses...
# 11   {"typeName":"cml","definition":{"dtdId":"asses...
# 12   {"typeName":"cml","definition":{"dtdId":"asses...
# 13   {"typeName":"cml","definition":{"dtdId":"asses...
# 14   {"typeName":"cml","definition":{"dtdId":"asses...
# 15   {"typeName":"cml","definition":{"dtdId":"asses...
# 16   {"typeName":"cml","definition":{"dtdId":"asses...
# 17   {"typeName":"cml","definition":{"dtdId":"asses...
# 18   {"typeName":"cml","definition":{"dtdId":"asses...
# 19   {"typeName":"cml","definition":{"dtdId":"asses...
# 20   {"typeName":"cml","definition":{"dtdId":"asses...
# 21   {"typeName":"cml","definition":{"dtdId":"asses...
# 22   {"typeName":"cml","definition":{"dtdId":"asses...
# 23   {"typeName":"cml","definition":{"dtdId":"asses...
# 24   {"typeName":"cml","definition":{"dtdId":"asses...
# 25   {"typeName":"cml","definition":{"dtdId":"asses...
# 26   {"typeName":"cml","definition":{"dtdId":"asses...
# 27   {"typeName":"cml","definition":{"dtdId":"asses...
# 28   {"typeName":"cml","definition":{"dtdId":"asses...
# 29   {"typeName":"cml","definition":{"dtdId":"asses...
# ..                                                 ...
# 439  {"typeName":"cml","definition":{"dtdId":"asses...
# 440  {"typeName":"cml","definition":{"dtdId":"asses...
# 441  {"typeName":"cml","definition":{"dtdId":"asses...
# 442  {"typeName":"cml","definition":{"dtdId":"asses...
# 443  {"typeName":"cml","definition":{"dtdId":"asses...
# 444  {"typeName":"cml","definition":{"dtdId":"asses...
# 445  {"typeName":"cml","definition":{"dtdId":"asses...
# 446  {"typeName":"cml","definition":{"dtdId":"asses...
# 447  {"typeName":"cml","definition":{"dtdId":"asses...
# 448  {"typeName":"cml","definition":{"dtdId":"asses...
# 449  {"typeName":"cml","definition":{"dtdId":"asses...
# 450  {"typeName":"cml","definition":{"dtdId":"asses...
# 451  {"typeName":"cml","definition":{"dtdId":"asses...
# 452  {"typeName":"cml","definition":{"dtdId":"asses...
# 453  {"typeName":"cml","definition":{"dtdId":"asses...
# 454  {"typeName":"cml","definition":{"dtdId":"asses...
# 455  {"typeName":"cml","definition":{"dtdId":"asses...
# 456  {"typeName":"cml","definition":{"dtdId":"asses...
# 457  {"typeName":"cml","definition":{"dtdId":"asses...
# 458  {"typeName":"cml","definition":{"dtdId":"asses...
# 459  {"typeName":"cml","definition":{"dtdId":"asses...
# 460  {"typeName":"cml","definition":{"dtdId":"asses...
# 461  {"typeName":"cml","definition":{"dtdId":"asses...
# 462  {"typeName":"cml","definition":{"dtdId":"asses...
# 463  {"typeName":"cml","definition":{"dtdId":"asses...
# 464  {"typeName":"cml","definition":{"dtdId":"asses...
# 465  {"typeName":"cml","definition":{"dtdId":"asses...
# 466  {"typeName":"cml","definition":{"dtdId":"asses...
# 467  {"typeName":"cml","definition":{"dtdId":"asses...
# 468  {"typeName":"cml","definition":{"dtdId":"asses...
#
#     assessment_question_update_ts
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3         2017-08-06 20:50:40.598
# 4          2018-08-15 04:29:12.58
# 5         2018-04-28 13:28:02.083
# 6         2017-09-20 19:14:27.853
# 7         2018-08-15 02:56:08.717
# 8         2018-04-28 13:27:51.684
# 9         2017-08-05 14:40:48.375
# 10        2017-08-06 20:50:40.603
# 11        2017-10-24 22:57:08.773
# 12        2017-09-24 20:32:06.036
# 13        2017-09-15 21:30:21.161
# 14        2018-04-28 13:28:02.391
# 15        2017-09-15 20:28:21.274
# 16        2017-08-05 14:40:48.361
# 17        2018-08-12 17:45:58.678
# 18        2017-10-15 23:04:59.236
# 19        2018-04-28 13:28:02.586
# 20        2017-09-06 13:27:07.245
# 21        2018-04-28 13:28:00.382
# 22        2017-08-05 15:45:30.843
# 23         2017-10-16 12:55:12.42
# 24        2017-09-16 10:30:55.997
# 25        2018-04-28 13:27:54.095
# 26        2017-09-16 11:25:38.569
# 27        2017-08-05 16:46:26.296
# 28        2017-11-25 09:42:21.801
# 29        2018-04-28 13:27:53.182
# ..                            ...
# 439       2018-08-15 01:58:56.965
# 440       2017-10-04 12:41:55.459
# 441       2018-04-28 13:27:56.298
# 442       2017-10-04 08:00:47.935
# 443        2017-09-20 19:14:27.85
# 444       2018-04-28 13:27:45.987
# 445       2017-08-05 15:45:30.845
# 446       2017-10-03 23:43:00.017
# 447       2017-09-16 10:38:03.451
# 448       2017-12-14 13:52:23.977
# 449       2018-08-15 04:29:12.572
# 450       2017-10-15 23:04:59.237
# 451       2017-10-15 14:59:51.493
# 452       2018-04-28 13:27:59.692
# 453       2018-04-28 13:27:56.597
# 454       2017-09-17 09:10:09.886
# 455       2017-10-24 23:23:36.474
# 456       2018-04-28 13:27:48.085
# 457       2018-04-28 13:27:57.892
# 458       2017-09-16 11:08:31.351
# 459       2018-04-28 13:27:46.584
# 460       2018-04-28 13:27:55.097
# 461       2018-04-28 13:27:49.479
# 462       2017-09-15 21:25:38.992
# 463       2017-10-03 23:43:00.039
# 464       2018-04-28 13:27:53.192
# 465       2017-10-16 14:52:41.759
# 466       2018-04-26 19:53:58.756
# 467       2018-04-28 13:27:59.781
# 468       2017-08-06 19:05:16.384
#
# [469 rows x 6 columns]

# %%
import dask.dataframe as dd

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
