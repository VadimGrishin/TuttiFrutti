# %% [markdown]
# ## Урок 1
# #### Задание 4

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import time
import matplotlib.animation as animation
from collections import deque
# %matplotlib notebook

# %%
def init_y():
    for i in range(N_WIND):
        y.append(float(next(f).strip()))


def pltsin(ax):
    
    if ax.lines:
        for line in ax.lines:
            #x[i] = i
            line.set_xdata(x)
            line.set_ydata(y[-N_WIND:])
    else:
        ax.plot(x, y[-N_WIND:])
        
    fig.canvas.draw()

N_WIND = 50
    
f = open("C:\\Users\\EGOR\\Desktop\\Новая папка\\data.txt")

x = range(N_WIND)
y = []    
    
fig,ax = plt.subplots(1,1)
ax.set_ylabel('Y')
ax.set_xlim(0,N_WIND)
ax.set_ylim(0,50)

init_y()

while True:
    try:
        c =  float(next(f).strip())
        y.append(c)
        pltsin(ax)
    except:
        pass
   
    time.sleep(0.2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c2efdab327a8> in <module>
#      38         pass
#      39
# ---> 40     time.sleep(0.2)
#      41
#      42
#
# KeyboardInterrupt:
